# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy  as np
import requests
import scipy
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn

# %%
file_url=input()
# Out:
#  https://www.football-data.co.uk/new/ROU.csv

# %%
df=pd.read_csv(file_url)

# %%
df.tail(100)
# Out:
#       Country  League     Season        Date   Time                Home  \
# 2836  Romania  Liga 1  2021/2022  19/03/2022  18:30     Farul Constanta
# 2837  Romania  Liga 1  2021/2022  20/03/2022  14:00      Din. Bucuresti
# 2838  Romania  Liga 1  2021/2022  20/03/2022  17:00            FC Arges
# 2839  Romania  Liga 1  2021/2022  21/03/2022  18:30             Mioveni
# 2840  Romania  Liga 1  2021/2022  01/04/2022  15:30      U Craiova 1948
# ...       ...     ...        ...         ...    ...                 ...
# 2931  Romania  Liga 1  2022/2023  07/08/2022  14:00  Sepsi Sf. Gheorghe
# 2932  Romania  Liga 1  2022/2023  07/08/2022  16:30  Chindia Targoviste
# 2933  Romania  Liga 1  2022/2023  07/08/2022  19:30      U Craiova 1948
# 2934  Romania  Liga 1  2022/2023  08/08/2022  16:00     FC Hermannstadt
# 2935  Romania  Liga 1  2022/2023  08/08/2022  19:00         FC Botosani
#
#                     Away  HG  AG Res    PH    PD    PA  MaxH  MaxD  MaxA  \
# ...
